# %% [markdown]
# # Arreglar el gráfico (Core)
# ## Arreglar el Código en Python, Pandas y Matplotlib

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# ### Objetivo
#
# El objetivo de esta actividad es consolidar tus conocimientos en Python, Pandas y Matplotlib. Se te proporcionará un código con errores que necesitas identificar y corregir. Esta actividad te ayudará a desarrollar habilidades de depuración y a reforzar tu comprensión de los conceptos básicos de programación, manipulación de datos y visualización gráfica.
#
# ### Descripción del Ejercicio
#
# A continuación, se presenta un código con errores que contiene tareas de Python, Pandas y Matplotlib. Tu tarea es encontrar y corregir los errores para que el código funcione correctamente y genere las visualizaciones adecuadas.
#
# ### **1. Tareas**
#    * Identificar y corregir errores en la carga de datos: Asegúrate de que los datos se carguen correctamente en un DataFrame de Pandas.
#    * Corregir la conversión de la columna ‘fecha’ a formato datetime: Asegúrate de que la columna ‘fecha’ se convierta correctamente al formato de fecha y hora.
#    * Arreglar los gráficos generados por Matplotlib: Asegúrate de que los gráficos de líneas, dispersión e histograma se generen correctamente.
#
# ### Instrucciones:
# 1. Cargar los Datos:
#    * Revisa cómo se están cargando los datos en el DataFrame. Corrige cualquier error relacionado con la carga de datos.
# 2. Conversión de la Columna ‘Fecha’:
#    * Asegúrate de que la columna ‘fecha’ se esté convirtiendo correctamente a formato datetime.
#    * Genera estadísticas descriptivas del DataFrame utilizando el método describe().
# 3. Limpieza de Datos
#    * Corregir los Gráficos:
#    * Revisa el código para generar los gráficos de Matplotlib. Asegúrate de que se estén utilizando las columnas correctas y que las visualizaciones sean precisas.

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### **1. Tareas**
#    * Identificar y corregir errores en la carga de datos: Asegúrate de que los datos se carguen correctamente en un DataFrame de Pandas.
#    * Corregir la conversión de la columna ‘fecha’ a formato datetime: Asegúrate de que la columna ‘fecha’ se convierta correctamente al formato de fecha y hora.
#    * Arreglar los gráficos generados por Matplotlib: Asegúrate de que los gráficos de líneas, dispersión e histograma se generen correctamente.

# %% [markdown]
# ## **Código con Errores**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de ejemplo en formato CSV*
data = """
fecha,ventas
2023-01-01,200
2023-01-02,220
2023-01-03,210
2023-01-04,205
2023-01-05,215
2023-01-06,225
"""

# Cargar los datos en un DataFrame de Pandas*
df = pd.read_csv(pd.compat.StringIO(data))

# Convertir la columna 'fecha' a formato datetime*
df['fecha'] = pd.to_datetime(df['fechas'])

# Gráfico de líneas de las ventas*
plt.figure(figsize=(10, 6))
plt.plot(df['fecha'], df['ventas'])
plt.title("Ventas Diarias")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.show()

# Crear un gráfico de dispersión*
plt.scatter(df['fecha'], df['ventas'])
plt.title("Ventas Diarias")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.show()

# Crear un histograma de las ventas*
plt.hist(df['ventas'], bins=5, color='skyblue', edgecolor='black')
plt.title("Distribución de Ventas")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 16
#       5 data = """
#       6 fecha,ventas
#       7 2023-01-01,200
#    (...)
#      12 2023-01-06,225
#      13 """
#      15 # Cargar los datos en un DataFrame de Pandas*
# ---> 16 df = pd.read_csv(pd.compat.StringIO(data))
#      18 # Convertir la columna 'fecha' a formato datetime*
#      19 df['fecha'] = pd.to_datetime(df['fechas'])
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %% [markdown]
# ## **Corregido**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO  # Importar StringIO para cargar datos de ejemplo

# Datos de ejemplo en formato CSV
data = """
fecha,ventas
2023-01-01,200
2023-01-02,220
2023-01-03,210
2023-01-04,205
2023-01-05,215
2023-01-06,225
"""

# Cargar los datos en un DataFrame de Pandas
df = pd.read_csv(StringIO(data))  # Usar StringIO para leer el CSV de ejemplo

# Convertir la columna 'fecha' a formato datetime
df['fecha'] = pd.to_datetime(df['fecha'])  

# Gráfico de líneas de las ventas
plt.figure(figsize=(10, 6))
plt.plot(df['fecha'], df['ventas'], marker='o')  # Agregar marcadores para mayor claridad
plt.title("Ventas Diarias")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mejor legibilidad
plt.grid()
plt.tight_layout()  # Ajustar el diseño
plt.show()

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(df['fecha'], df['ventas'], color='orange')
plt.title("Ventas Diarias (Gráfico de Dispersión)")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mejor legibilidad
plt.grid()
plt.tight_layout()  # Ajustar el diseño
plt.show()

# Crear un histograma de las ventas
plt.figure(figsize=(10, 6))
plt.hist(df['ventas'], bins=5, color='skyblue', edgecolor='black')
plt.title("Distribución de Ventas")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.grid()
plt.tight_layout()  # Ajustar el diseño
plt.show()
